# %% [markdown]
# <a href="https://colab.research.google.com/github/shimjide123/datman/blob/main/ps3_by_yu_nong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader as pdr
from pandas_datareader import wb
from pandas.io.formats.style import Styler
#s4 = Styler(df4, uuid_len=0, cell_ids=False)

from google.colab import files

# %%
import numpy as np

# %% [markdown]
# # Problem set 3

# %% [markdown]
# ##First project:
#
# exploring the way child marriage affect children and youth's completion of education, as well as correlaton of level of child and youth education, the frequencies of violence/terrorist/extremist activties, and the use of child labor. Given the definition of international Labor Organization (ILO) that recruiting children and youth into armed conflict is the worst form of child labour. So 4 datasets are used.

# %% [markdown]
# ###1st Dataset: Marrgage rates of children by country

# %%
Marriage=pd.read_excel('https://github.com/shimjide123/datman/raw/main/UNICEF%20Child-marriage-database.xlsx')

# %%
Marriage
# Out:
#                                    Countries and areas  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                          Afghanistan
# 4                                              Albania
# ..                                                 ...
# 232                                                NaN
# 233                                           Source:
# 234                                                NaN
# 235  Prepared by the Data and Analytics Section; Di...
# 236                                      Contact us:
#
#                                     Child marriage (%)  \
# 0                                                  NaN
# 1                             Female Married by 15 (%)
# 2                                                  NaN
# 3                                                4.201
# ...

# %%
Marriage.head()
# Out:
#   Countries and areas        Child marriage (%)                Unnamed: 2  \
# 0                 NaN                       NaN                       NaN
# 1                 NaN  Female Married by 15 (%)  Female Married by 18 (%)
# 2                 NaN                       NaN                       NaN
# 3         Afghanistan                     4.201                    28.257
# 4             Albania                     1.387                    11.761
#
#                Unnamed: 3
# 0                     NaN
# 1  Male Married by 18 (%)
# 2                     NaN
# 3                     7.3
# 4                     1.2

# %%
Marriage.rename(columns={'Child marriage (%)': 'Female_married_by_15(%)'}, inplace=True)
Marriage.rename(columns={'Unnamed: 2': 'Female_married_by_18(%)'}, inplace=True)
Marriage.rename(columns={'Unnamed: 3': 'Male_married_by_18(%)'}, inplace=True)
Marriage.rename(columns={'Countries and areas': 'Countries'}, inplace=True)

# %%
Marriage['Female_married_by_18(%)'] = pd.to_numeric(Marriage['Female_married_by_18(%)'], errors='coerce')
Marriage['Female_married_by_15(%)'] = pd.to_numeric(Marriage['Female_married_by_15(%)'], errors='coerce')
Marriage['Male_married_by_18(%)'] = pd.to_numeric(Marriage['Male_married_by_18(%)'], errors='coerce')

# %%
Marriage.dtypes
# Out:
# Countries                   object
# Female_married_by_15(%)    float64
# Female_married_by_18(%)    float64
# Male_married_by_18(%)      float64
# dtype: object

# %%
Marriage.reset_index(drop=True)
Marriage.head()
# Out:
#      Countries  Female_married_by_15(%)  Female_married_by_18(%)  \
# 0          NaN                      NaN                      NaN
# 1          NaN                      NaN                      NaN
# 2          NaN                      NaN                      NaN
# 3  Afghanistan                    4.201                   28.257
# 4      Albania                    1.387                   11.761
#
#    Male_married_by_18(%)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    7.3
# 4                    1.2

# %%
Marriage=Marriage.fillna('') #a command of cleaning up the "NaN" values #aok no NaN is a python code for missing
Marriage.head()
# Out:
#      Countries Female_married_by_15(%) Female_married_by_18(%)  \
# 0
# 1
# 2
# 3  Afghanistan                   4.201                  28.257
# 4      Albania                   1.387                  11.761
#
#   Male_married_by_18(%)
# 0
# 1
# 2
# 3                   7.3
# 4                   1.2

# %%
#Since the first 3 rows are empty, I will drop it
Marriage=Marriage.drop(Marriage.index[[0,1,2]],axis=0)

# %%
Marriage.reset_index(drop=True) #reorder the indexes
# Out:
#                                              Countries  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                              Andorra
# 4                                               Angola
# ..                                                 ...
# 229
# 230                                           Source:
# 231
# 232  Prepared by the Data and Analytics Section; Di...
# 233                                      Contact us:
#
#     Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)
# 0                     4.201                  28.257                   7.3
# 1                     1.387                  11.761                   1.2
# 2                       0.0                     3.8
# 3
# 4                     7.902                  30.331                   6.0
# ...

# %%
#according to the original file, Eastern & Southern Africa and West & Central Africa fall under the category of Sub-saharan Africa, and Eastern Europe & Central Asia and Western Europe fall under the category of Europe & Central Asia. Thus i dropped these 4 rows due to repetition.
Marriage=Marriage.drop([209,210,216,217])

# %%
Marriage.head(218)
# Out:
#        Countries Female_married_by_15(%) Female_married_by_18(%)  \
# 3    Afghanistan                   4.201                  28.257
# 4        Albania                   1.387                  11.761
# 5        Algeria                     0.0                     3.8
# 6        Andorra
# 7         Angola                   7.902                  30.331
# ..           ...                     ...                     ...
# 220
# 221
# 222       Notes:
# 223
# 224
#
#     Male_married_by_18(%)
# 3                     7.3
# 4                     1.2
# 5
# 6
# 7                     6.0
# ..                    ...
# 220
# 221
# 222
# 223
# 224
#
# [218 rows x 4 columns]

# %% [markdown]
# ###2nd dataset for the 1st project: percentage of children and youth completing their education at school.
#
# the link is:https://data.unicef.org/topic/education/overview/

# %%
Completion=pd.read_excel('https://github.com/shimjide123/datman/raw/main/Completion_rate_2022_formatted%20(1).xlsx')

# %%
Completion.head()
# Out:
#      Countries Regions Development Regions      Total  Female_completion_rate  \
# 0  Afghanistan      SA     Least Developed  22.895340               14.365360
# 1      Albania     ECA      More Developed  77.947960               79.857063
# 2      Algeria    MENA      Less Developed  46.431679               59.164452
# 3      Andorra     ECA      More Developed        NaN                     NaN
# 4       Angola     SSA     Least Developed  18.743900               15.210190
#
#    Male_completion_rate  Rural_completion_rate  Urban_completion_rate  \
# 0             32.315559              16.607441              38.913071
# 1             76.226807              69.100288              83.281387
# 2             34.630589              35.473091              52.634720
# 3                   NaN                    NaN                    NaN
# 4             23.698139               3.587311              24.791439
#
#     female_population  male_population  Urban_percentage
# ...

# %%
#in this step, I will clean the dataset by removing the "NaN".
Completion=Completion.fillna('')
Completion.head()
# Out:
#      Countries Regions Development Regions      Total Female_completion_rate  \
# 0  Afghanistan      SA     Least Developed   22.89534               14.36536
# 1      Albania     ECA      More Developed   77.94796              79.857063
# 2      Algeria    MENA      Less Developed  46.431679              59.164452
# 3      Andorra     ECA      More Developed
# 4       Angola     SSA     Least Developed    18.7439               15.21019
#
#   Male_completion_rate Rural_completion_rate Urban_completion_rate  \
# 0            32.315559             16.607441             38.913071
# 1            76.226807             69.100288             83.281387
# 2            34.630589             35.473091              52.63472
# 3
# 4            23.698139              3.587311             24.791439
#
#    female_population male_population Urban_percentage
# 0          1380667.0       1458082.0         0.254949
# 1            53510.0         61841.0         0.603189
# ...

# %%
Completion.dtypes
# Out:
# Countries                 object
# Regions                   object
# Development Regions       object
# Total                     object
# Female_completion_rate    object
# Male_completion_rate      object
# Rural_completion_rate     object
# Urban_completion_rate     object
#  female_population        object
# male_population           object
# Urban_percentage          object
# dtype: object

# %%
Completion['Total'] = pd.to_numeric(Completion['Total'], errors='coerce')
Completion['Female_completion_rate'] = pd.to_numeric(Completion['Female_completion_rate'], errors='coerce')
Completion['Male_completion_rate'] = pd.to_numeric(Completion['Male_completion_rate'], errors='coerce')
Completion['Rural_completion_rate'] = pd.to_numeric(Completion['Rural_completion_rate'], errors='coerce')
Completion['Urban_completion_rate'] = pd.to_numeric(Completion['Urban_completion_rate'], errors='coerce')
Completion[' female_population'] = pd.to_numeric(Completion[' female_population'], errors='coerce')
Completion['male_population'] = pd.to_numeric(Completion['male_population'], errors='coerce')
Completion['Urban_percentage'] = pd.to_numeric(Completion['Urban_percentage'], errors='coerce')

# %%
Completion=Completion.fillna('')
Completion.head(250)
# Out:
#                      Countries Regions Development Regions      Total  \
# 0                  Afghanistan      SA     Least Developed   22.89534
# 1                      Albania     ECA      More Developed   77.94796
# 2                      Algeria    MENA      Less Developed  46.431679
# 3                      Andorra     ECA      More Developed
# 4                       Angola     SSA     Least Developed    18.7439
# ..                         ...     ...                 ...        ...
# 214         Sub-Saharan Africa     SSA
# 215  Eastern & Southern Africa
# 216      West & Central Africa
# 217  Least developed countries                         LDC
# 218                      World
#
#     Female_completion_rate Male_completion_rate Rural_completion_rate  \
# 0                 14.36536            32.315559             16.607441
# 1                79.857063            76.226807             69.100288
# 2                59.164452            34.630589             35.473091
# 3
# ...

# %%
#according to the original file, Eastern & Southern Africa and West & Central Africa fall under the category of Sub-saharan Africa, and Eastern Europe & Central Asia and Western Europe fall under the category of Europe & Central Asia. Thus i dropped these 4 rows due to repetition.
Completion=Completion.drop([208,209,215,216])

# %%
Completion.head(220)
# Out:
#                      Countries Regions Development Regions      Total  \
# 0                  Afghanistan      SA     Least Developed   22.89534
# 1                      Albania     ECA      More Developed   77.94796
# 2                      Algeria    MENA      Less Developed  46.431679
# 3                      Andorra     ECA      More Developed
# 4                       Angola     SSA     Least Developed    18.7439
# ..                         ...     ...                 ...        ...
# 212              North America
# 213                 South Asia      SA
# 214         Sub-Saharan Africa     SSA
# 217  Least developed countries                         LDC
# 218                      World
#
#     Female_completion_rate Male_completion_rate Rural_completion_rate  \
# 0                 14.36536            32.315559             16.607441
# 1                79.857063            76.226807             69.100288
# 2                59.164452            34.630589             35.473091
# ...

# %% [markdown]
# ### 1st Merge: the 1st and the 2nd datasets

# %%
Marriage_Completion = pd.merge(Marriage, Completion, how='outer', on=['Countries'],indicator=True) #outer=keep all
Marriage_Completion #.head(131)
#aok aha! mistake! turkey should have merged!!
# so need to replace on condition:
#auto.loc[auto['foreign'] =='Domestic', 'colOfOnes']  = '100'
# Out:
#                       Countries Female_married_by_15(%)  \
# 0                   Afghanistan                   4.201
# 1                       Albania                   1.387
# 2                       Algeria                     0.0
# 3                       Andorra
# 4                        Angola                   7.902
# ..                          ...                     ...
# 246         Population coverage                     NaN
# 247         East Asia & Pacific                     NaN
# 248       Europe & Central Asia                     NaN
# 249   Latin America & Caribbean                     NaN
# 250  Middle East & North Africa                     NaN
#
#     Female_married_by_18(%) Male_married_by_18(%) Regions Development Regions  \
# 0                    28.257                   7.3      SA     Least Developed
# 1                    11.761                   1.2     ECA      More Developed
# 2                       3.8                          MENA      Less Developed
# ...

# %%
order=['Countries','Regions','Development Regions','Female_married_by_15(%)','Female_married_by_18(%)','Male_married_by_18(%)','Total','Female_completion_rate', 'Male_completion_rate','Rural_completion_rate','Urban_completion_rate','Urban_percentage',	'_merge']

# %%
Marriage_Completion=Marriage_Completion[order]
Marriage_Completion.head()
# Out:
#      Countries Regions Development Regions Female_married_by_15(%)  \
# 0  Afghanistan      SA     Least Developed                   4.201
# 1      Albania     ECA      More Developed                   1.387
# 2      Algeria    MENA      Less Developed                     0.0
# 3      Andorra     ECA      More Developed
# 4       Angola     SSA     Least Developed                   7.902
#
#   Female_married_by_18(%) Male_married_by_18(%)      Total  \
# 0                  28.257                   7.3   22.89534
# 1                  11.761                   1.2   77.94796
# 2                     3.8                        46.431679
# 3
# 4                  30.331                   6.0    18.7439
#
#   Female_completion_rate Male_completion_rate Rural_completion_rate  \
# 0               14.36536            32.315559             16.607441
# 1              79.857063            76.226807             69.100288
# 2              59.164452            34.630589             35.473091
# 3
# ...

# %%
Marriage_Completion.dtypes
# Out:
# Countries                    object
# Regions                      object
# Development Regions          object
# Female_married_by_15(%)      object
# Female_married_by_18(%)      object
# Male_married_by_18(%)        object
# Total                        object
# Female_completion_rate       object
# Male_completion_rate         object
# Rural_completion_rate        object
# Urban_completion_rate        object
# Urban_percentage             object
# _merge                     category
# dtype: object

# %%
Marriage_Completion['Total'] = pd.to_numeric(Marriage_Completion['Total'], errors='coerce')
Marriage_Completion['Female_completion_rate'] = pd.to_numeric(Marriage_Completion['Female_completion_rate'], errors='coerce')
Marriage_Completion['Male_completion_rate'] = pd.to_numeric(Marriage_Completion['Male_completion_rate'], errors='coerce')
Marriage_Completion['Rural_completion_rate'] = pd.to_numeric(Marriage_Completion['Rural_completion_rate'], errors='coerce')
Marriage_Completion['Urban_completion_rate'] = pd.to_numeric(Marriage_Completion['Urban_completion_rate'], errors='coerce')
Marriage_Completion['Urban_percentage'] = pd.to_numeric(Marriage_Completion['Urban_percentage'], errors='coerce')
Marriage_Completion['Female_married_by_15(%)'] = pd.to_numeric(Marriage_Completion['Female_married_by_15(%)'], errors='coerce')
Marriage_Completion['Female_married_by_18(%)'] = pd.to_numeric(Marriage_Completion['Female_married_by_15(%)'], errors='coerce')
Marriage_Completion['Male_married_by_18(%)'] = pd.to_numeric(Marriage_Completion['Female_married_by_15(%)'], errors='coerce')
# Out:
# <ipython-input-642-e70c34c63aa7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Marriage_Completion['Total'] = pd.to_numeric(Marriage_Completion['Total'], errors='coerce')
# <ipython-input-642-e70c34c63aa7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Marriage_Completion['Female_completion_rate'] = pd.to_numeric(Marriage_Completion['Female_completion_rate'], errors='coerce')
# <ipython-input-642-e70c34c63aa7>:3: SettingWithCopyWarning:
# ...

# %%
Marriage_Completion['_merge'].value_counts() #.plot(kind='barh')
# Out:
# both          231
# left_only      12
# right_only      8
# Name: _merge, dtype: int64

# %%
Marriage_Completion['Countries'][Marriage_Completion['_merge']=='left_only']
# Out:
# 126                         Netherlands (Kingdom of the)
# 184                                              Türkiye
# 228                                              SUMMARY
# 229                                East Asia and Pacific
# 230                              Europe and Central Asia
# 231                          Latin America and Caribbean
# 232                         Middle East and North Africa
# 238                                               Notes:
# 239                               Indicator definitions:
# 240                                             Source:
# 241    Prepared by the Data and Analytics Section; Di...
# 242                                        Contact us:
# Name: Countries, dtype: object

# %%
Marriage_Completion['Countries'][Marriage_Completion['_merge']=='right_only']
# Out:
# 243    Kosovo under UNSC res. 1244*
# 244                     Netherlands
# 245                          Turkey
# 246             Population coverage
# 247             East Asia & Pacific
# 248           Europe & Central Asia
# 249       Latin America & Caribbean
# 250      Middle East & North Africa
# Name: Countries, dtype: object

# %%
Marriage_Completion.query("_merge=='left_only'")
# Bug identified: Netherlands (Kingdom) and Turkiye do not merge with Netherland and Turkey in the "right_only". Will fix it with replace on conditions.
# Out:
#                                              Countries Regions  \
# 126                       Netherlands (Kingdom of the)     NaN
# 184                                            Türkiye     NaN
# 228                                            SUMMARY     NaN
# 229                              East Asia and Pacific     NaN
# 230                            Europe and Central Asia     NaN
# 231                        Latin America and Caribbean     NaN
# 232                       Middle East and North Africa     NaN
# 238                                             Notes:     NaN
# 239                             Indicator definitions:     NaN
# 240                                           Source:      NaN
# 241  Prepared by the Data and Analytics Section; Di...     NaN
# 242                                      Contact us:       NaN
#
#     Development Regions Female_married_by_15(%) Female_married_by_18(%)  \
# 126                 NaN
# ...

# %%
Marriage_Completion.query("_merge=='right_only'")
#Bug identified: Netherland and Turkey do not merge with Netherlands (Kingdom) and Turkiye in the "left_only". Will fix it with replace on conditions in the next step.
# Out:
#                         Countries Regions Development Regions  \
# 243  Kosovo under UNSC res. 1244*     ECA
# 244                   Netherlands     ECA      More Developed
# 245                        Turkey     ECA      Less Developed
# 246           Population coverage
# 247           East Asia & Pacific     EAP
# 248         Europe & Central Asia     ECA
# 249     Latin America & Caribbean     LAC
# 250    Middle East & North Africa    MENA
#
#     Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)  \
# 243                     NaN                     NaN                   NaN
# 244                     NaN                     NaN                   NaN
# 245                     NaN                     NaN                   NaN
# 246                     NaN                     NaN                   NaN
# 247                     NaN                     NaN                   NaN
# 248                     NaN                     NaN                   NaN
# ...

# %%
Marriage_Completion.loc[Marriage_Completion['Countries']=='Netherlands (Kingdom of the)','Countries']='Netherlands'
Marriage_Completion.head(127)
# Out:
#        Countries Regions Development Regions Female_married_by_15(%)  \
# 0    Afghanistan      SA     Least Developed                   4.201
# 1        Albania     ECA      More Developed                   1.387
# 2        Algeria    MENA      Less Developed                     0.0
# 3        Andorra     ECA      More Developed
# 4         Angola     SSA     Least Developed                   7.902
# ..           ...     ...                 ...                     ...
# 122      Myanmar     EAP     Least Developed                   1.886
# 123      Namibia     SSA      Less Developed                   1.584
# 124        Nauru     EAP      Less Developed                     1.9
# 125        Nepal      SA     Least Developed                     7.9
# 126  Netherlands     NaN                 NaN
#
#     Female_married_by_18(%) Male_married_by_18(%)      Total  \
# 0                    28.257                   7.3   22.89534
# ...

# %%
Marriage.head(236)
# Out:
#                                              Countries  \
# 3                                          Afghanistan
# 4                                              Albania
# 5                                              Algeria
# 6                                              Andorra
# 7                                               Angola
# ..                                                 ...
# 232
# 233                                           Source:
# 234
# 235  Prepared by the Data and Analytics Section; Di...
# 236                                      Contact us:
#
#     Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)
# 3                     4.201                  28.257                   7.3
# 4                     1.387                  11.761                   1.2
# 5                       0.0                     3.8
# 6
# 7                     7.902                  30.331                   6.0
# ...

# %%
Marriage.loc[Marriage['Countries']=='Türkiye','Countries']='Turkey'
Marriage.loc[Marriage['Countries']=='Netherlands (Kingdom of the)','Countries']='Netherlands'
Completion.loc[Completion['Countries']=='Kosovo under UNSC res. 1244*','Countries']='Kosovo'

# %%
Completion.loc[Completion['Countries']=='East Asia & Pacific','Countries']='East Asia and Pacific'
Completion.loc[Completion['Countries']=='Europe & Central Asia','Countries']='Europe and Central Asia'
Completion.loc[Completion['Countries']=='Latin America & Caribbean','Countries']='Latin America and Caribbean'
Completion.loc[Completion['Countries']=='Middle East & North Africa','Countries']='Middle East and North Africa'

# %%
Completion.head (210)
# Out:
#                         Countries Regions Development Regions      Total  \
# 0                     Afghanistan      SA     Least Developed   22.89534
# 1                         Albania     ECA      More Developed   77.94796
# 2                         Algeria    MENA      Less Developed  46.431679
# 3                         Andorra     ECA      More Developed
# 4                          Angola     SSA     Least Developed    18.7439
# ..                            ...     ...                 ...        ...
# 205           Population coverage
# 206         East Asia and Pacific     EAP
# 207       Europe and Central Asia     ECA
# 210   Latin America and Caribbean     LAC
# 211  Middle East and North Africa    MENA
#
#     Female_completion_rate Male_completion_rate Rural_completion_rate  \
# 0                 14.36536            32.315559             16.607441
# 1                79.857063            76.226807             69.100288
# ...

# %%
RevisedMarriage_Completion = pd.merge(Marriage, Completion, how='outer', on=['Countries'],indicator=True)

# %%
RevisedMarriage_Completion['_merge'].value_counts()
# Out:
# both          237
# left_only       6
# right_only      2
# Name: _merge, dtype: int64

# %%
RevisedMarriage_Completion.query("_merge=='left_only'")
# Out:
#                                              Countries  \
# 228                                            SUMMARY
# 238                                             Notes:
# 239                             Indicator definitions:
# 240                                           Source:
# 241  Prepared by the Data and Analytics Section; Di...
# 242                                      Contact us:
#
#     Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)  \
# 228
# 238
# 239
# 240
# 241
# 242
#
#     Regions Development Regions Total Female_completion_rate  \
# 228     NaN                 NaN   NaN                    NaN
# 238     NaN                 NaN   NaN                    NaN
# 239     NaN                 NaN   NaN                    NaN
# 240     NaN                 NaN   NaN                    NaN
# 241     NaN                 NaN   NaN                    NaN
# 242     NaN                 NaN   NaN                    NaN
#
# ...

# %%
RevisedMarriage_Completion.query("_merge=='right_only'") #the values of kosovo only appear in the dataset of education completion rate
# Out:
#                Countries Female_married_by_15(%) Female_married_by_18(%)  \
# 243               Kosovo                     NaN                     NaN
# 244  Population coverage                     NaN                     NaN
#
#     Male_married_by_18(%) Regions Development Regions Total  \
# 243                   NaN     ECA                      87.2
# 244                   NaN
#
#     Female_completion_rate Male_completion_rate Rural_completion_rate  \
# 243                   86.6                 87.9                  85.2
# 244
#
#     Urban_completion_rate  female_population male_population Urban_percentage  \
# 243                  90.2
# 244
#
#          _merge
# 243  right_only
# 244  right_only

# %%
RevisedMarriage_Completion.query("_merge=='left_only'")
# Out:
#                                              Countries  \
# 228                                            SUMMARY
# 238                                             Notes:
# 239                             Indicator definitions:
# 240                                           Source:
# 241  Prepared by the Data and Analytics Section; Di...
# 242                                      Contact us:
#
#     Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)  \
# 228
# 238
# 239
# 240
# 241
# 242
#
#     Regions Development Regions Total Female_completion_rate  \
# 228     NaN                 NaN   NaN                    NaN
# 238     NaN                 NaN   NaN                    NaN
# 239     NaN                 NaN   NaN                    NaN
# 240     NaN                 NaN   NaN                    NaN
# 241     NaN                 NaN   NaN                    NaN
# 242     NaN                 NaN   NaN                    NaN
#
# ...

# %%
#3rd dataset: the percentage of child labor by country.
#link is: https://data.unicef.org/topic/child-protection/child-labour/

# %%
# !pip install fuzzywuzzy
#import fuzzywuzzy
#from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
labor=pd.read_excel('https://github.com/shimjide123/datman/raw/main/XLS_Child-labour-database_June-2023%20(1).xlsx')

# %%
display(RevisedMarriage_Completion, labor)
# Out:
#                                              Countries  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                              Andorra
# 4                                               Angola
# ..                                                 ...
# 240                                           Source:
# 241  Prepared by the Data and Analytics Section; Di...
# 242                                      Contact us:
# 243                                             Kosovo
# 244                                Population coverage
#
#     Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)  \
# 0                     4.201                  28.257                   7.3
# 1                     1.387                  11.761                   1.2
# 2                       0.0                     3.8
# 3
# ...

# %%
Marriage_Completion_labor=labor.merge(RevisedMarriage_Completion, on='Countries', how='outer')
#here I merge the datasets of child labor rate, child marriage rate, and the rate of school completion.

# %%
labor["best_match"] = labor["Countries"].map(lambda x: process.extractOne(x,Marriage_Completion["Countries"])[0])

# %%
Marriage_Completion_labor.head(130)
# Out:
#                         Countries Total_Child_labor Male_Child_labor  \
# 0                     Afghanistan                13             14.2
# 1                         Albania               3.3              3.6
# 2                         Algeria               2.5              2.9
# 3                         Andorra                 -                -
# 4                          Angola            18.724             16.6
# ..                            ...               ...              ...
# 125                         Nepal             21.71            20.29
# 126  Netherlands (Kingdom of the)                 -                -
# 127                   New Zealand                 -                -
# 128                     Nicaragua                 -                -
# 129                         Niger            34.395           34.051
#
#     Female_Child_labor Female_married_by_15(%) Female_married_by_18(%)  \
# ...

# %%
Marriage_Completion_labor['_merge'].value_counts() #.plot(kind='barh')
# Out:
# both          237
# left_only       6
# right_only      2
# Name: _merge, dtype: int64

# %%
Marriage_Completion_labor.query("_merge=='left_only'")
# Out:
#                                              Countries Total_Child_labor  \
# 230                                            SUMMARY               NaN
# 240                                             Notes:               NaN
# 241                             Indicator definitions:               NaN
# 242                                           Source:                NaN
# 243  Prepared by the Data and Analytics Section; Di...               NaN
# 244                                      Contact us:                 NaN
#
#     Male_Child_labor Female_Child_labor Female_married_by_15(%)  \
# 230              NaN                NaN
# 240              NaN                NaN
# 241              NaN                NaN
# 242              NaN                NaN
# 243              NaN                NaN
# 244              NaN                NaN
#
#     Female_married_by_18(%) Male_married_by_18(%) Regions Development Regions  \
# ...

# %%
Marriage_Completion_labor.head(240)
# Out:
#                      Countries Total_Child_labor Male_Child_labor  \
# 0                  Afghanistan                13             14.2
# 1                      Albania               3.3              3.6
# 2                      Algeria               2.5              2.9
# 3                      Andorra                 -                -
# 4                       Angola            18.724             16.6
# ..                         ...               ...              ...
# 235              North America               NaN              NaN
# 236                 South Asia               NaN              NaN
# 237         Sub-Saharan Africa               NaN              NaN
# 238  Least developed countries               NaN              NaN
# 239                      World               NaN              NaN
#
#     Female_Child_labor Female_married_by_15(%) Female_married_by_18(%)  \
# 0                 11.7                   4.201                  28.257
# ...

# %%
labor.loc[labor['Countries']=='Netherlands (Kingdom of the)','Countries']='Netherlands'
labor.loc[labor['Countries']=='Türkiye','Countries']='Turkey'
labor.head(187)
# Out:
#                     Countries Total_Child_labor Male_Child_labor  \
# 0                 Afghanistan                13             14.2
# 1                     Albania               3.3              3.6
# 2                     Algeria               2.5              2.9
# 3                     Andorra                 -                -
# 4                      Angola            18.724             16.6
# ..                        ...               ...              ...
# 182       Trinidad and Tobago              0.76            0.722
# 183                   Tunisia             2.255             3.02
# 184                    Turkey             3.831            4.073
# 185              Turkmenistan             0.281             0.43
# 186  Turks and Caicos Islands               6.1              8.7
#
#     Female_Child_labor
# 0                 11.7
# 1                    3
# 2                    2
# 3                    -
# 4                19.87
# ..                 ...
# ...

# %%
Marriage_Completion_labor=labor.merge(RevisedMarriage_Completion, on='Countries', how='outer')
Marriage_Completion_labor.head(220)
# Out:
#        Countries Total_Child_labor Male_Child_labor Female_Child_labor  \
# 0    Afghanistan                13             14.2               11.7
# 1        Albania               3.3              3.6                  3
# 2        Algeria               2.5              2.9                  2
# 3        Andorra                 -                -                  -
# 4         Angola            18.724             16.6              19.87
# ..           ...               ...              ...                ...
# 215                            NaN              NaN                NaN
# 216                            NaN              NaN                NaN
# 217                            NaN              NaN                NaN
# 218                            NaN              NaN                NaN
# 219                            NaN              NaN                NaN
#
#     Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)  \
# ...

# %%
# This is my 4th dataset, which is about freqencies of violence/terrorist activities by country, by merging this data,
#I hope to explore the correlation of education completion rate and the activeness of social unrest.
#lack of education opportunity may somewhat drive up conflict, because people without education are excluded from decent work, in this case participanting in conflict may be seen as the last resort.
#children lacking education opportunitites are likely used in armed conflict, which is also a form of child labor according to International labor organization (ILO).

# %%
#the link is: https://www.visionofhumanity.org/public-release-data/

# %%
Violence=pd.read_excel("https://github.com/shimjide123/datman/raw/main/GTI-2023-Overall-scores-2011-2022.xlsx")

# %%
Violence.head()
# Out:
#         Country  Rank     Score  Incidents  Fatalities  Injuries  Hostages
# 0   Afghanistan     1  8.822244        225         633       897         0
# 1  Burkina Faso     2  8.564101        310        1135       496        84
# 2       Somalia     3  8.463031        299         755      1001         0
# 3          Mali     4  8.412392        272         944       376        24
# 4         Syria     5  8.161243        197         447       451         2

# %%
Violence.rename(columns={'Country': 'Countries'}, inplace=True)

# %%
Firstproject=Violence.merge(Merged2, on='Countries', how='outer')

# %%
Firstproject.head()
# Out:
#       Countries  Rank     Score  Incidents  Fatalities  Injuries  Hostages  \
# 0   Afghanistan   1.0  8.822244      225.0       633.0     897.0       0.0
# 1  Burkina Faso   2.0  8.564101      310.0      1135.0     496.0      84.0
# 2       Somalia   3.0  8.463031      299.0       755.0    1001.0       0.0
# 3          Mali   4.0  8.412392      272.0       944.0     376.0      24.0
# 4         Syria   5.0  8.161243      197.0       447.0     451.0       2.0
#
#   Regions Development Regions Total_Child_labor  ... Female_Child_labor  \
# 0      SA     Least Developed                13  ...               11.7
# 1     SSA     Least Developed            42.002  ...             39.908
# 2                                                ...
# 3     SSA     Least Developed              13.2  ...               11.6
# 4     NaN                 NaN               NaN  ...                NaN
#
#   Female_married_by_15(%) Female_married_by_18(%) Male_married_by_18(%)  \
# ...

# %%
Firstproject['_merge'].value_counts() #.plot(kind='barh')
Firstproject['Countries'][Firstproject['_merge']=='left_only']
Firstproject['Countries'][Firstproject['_merge']=='right_only']
# Out:
# Series([], Name: Countries, dtype: object)

# %%
pd.crosstab(Firstproject["Countries"],Firstproject["_merge"])
# Out:
# _merge                       both
# Countries
# Afghanistan                     1
# Albania                         1
# Angola                          1
# Armenia                         1
# Bangladesh                      1
# ...                           ...
# Ukraine                         1
# United Republic of Tanzania     1
# Viet Nam                        1
# Zambia                          1
# Zimbabwe                        1
#
# [84 rows x 1 columns]

# %%
Firstproject['_merge'].value_counts()
# Out:
# both          84
# left_only      0
# right_only     0
# Name: _merge, dtype: int64

# %%
Firstproject=Firstproject.query("_merge == 'both'") #a bit subset here
Firstproject
# Out:
#                        Countries  Rank     Score  Incidents  Fatalities  \
# 0                    Afghanistan   1.0  8.822244      225.0       633.0
# 1                   Burkina Faso   2.0  8.564101      310.0      1135.0
# 3                           Mali   4.0  8.412392      272.0       944.0
# 5                       Pakistan   6.0  8.160153      298.0       643.0
# 7                        Nigeria   8.0  8.064811      120.0       385.0
# ..                           ...   ...       ...        ...         ...
# 216                        Tonga   NaN       NaN        NaN         NaN
# 218     Turks and Caicos Islands   NaN       NaN        NaN         NaN
# 219                       Tuvalu   NaN       NaN        NaN         NaN
# 220  United Republic of Tanzania   NaN       NaN        NaN         NaN
# 224                     Viet Nam   NaN       NaN        NaN         NaN
#
#      Injuries  Hostages Regions Development Regions Total_Child_labor  ...  \
# ...

# %%
Firstproject=Firstproject.fillna('')
Firstproject.head()
# Out:
#       Countries Rank     Score Incidents Fatalities Injuries Hostages Regions  \
# 0   Afghanistan  1.0  8.822244     225.0      633.0    897.0      0.0      SA
# 1  Burkina Faso  2.0  8.564101     310.0     1135.0    496.0     84.0     SSA
# 3          Mali  4.0  8.412392     272.0      944.0    376.0     24.0     SSA
# 5      Pakistan  6.0  8.160153     298.0      643.0    802.0     13.0      SA
# 7       Nigeria  8.0  8.064811     120.0      385.0    147.0     59.0     SSA
#
#   Development Regions Total_Child_labor  ... Female_Child_labor  \
# 0     Least Developed                13  ...               11.7
# 1     Least Developed            42.002  ...             39.908
# 3     Least Developed              13.2  ...               11.6
# 5      Less Developed              11.4  ...               10.1
# 7      Less Developed            31.494  ...             29.979
#
#   Female_married_by_15(%)  Female_married_by_18(%)  Male_married_by_18(%)  \
# ...

# %% [markdown]
# **Second project:** exploring correlation between population displacement at the country level and the national risk on food, water, population and disaster, as well as how they affect the index of happiness.

# %%
#1st dataset for the second project: displaced population by country due to conflict and disaster.
#Link to it: https://www.internal-displacement.org/database/displacement-data

displacement=pd.read_excel("https://github.com/shimjide123/datman/raw/main/IDMC_Internal_Displacement_Conflict-Violence_Disasters.xlsx")

# %%
displacement.head()
# Out:
#   ISO3         Name  Year  Conflict Stock Displacement  \
# 0  AB9   Abyei Area  2022                      56000.0
# 1  AFG  Afghanistan  2022                    4394000.0
# 2  AGO       Angola  2022                          NaN
# 3  ALB      Albania  2022                          NaN
# 4  ARG    Argentina  2022                          NaN
#
#    Conflict Stock Displacement (Raw)  Conflict Internal Displacements  \
# 0                            55705.0                          56000.0
# 1                          4393749.0                          32000.0
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#    Conflict Internal Displacements (Raw)  Disaster Internal Displacements  \
# 0                                55705.0                          29000.0
# ...

# %%
displacement.rename(columns={'Name': 'Countries_and_areas'}, inplace=True) #for the sake of merge

# %%
displacement.drop(columns=["ISO3","Conflict Stock Displacement (Raw)", "Conflict Internal Displacements (Raw)"],inplace=True) #these columus are no use

# %%
displacement.drop(columns=["Disaster Internal Displacements (Raw)", "Disaster Stock Displacement (Raw)"],inplace=True)
#dropping for the same reason, they are redundant.

# %%
displacement.head()
# Out:
#   Countries_and_areas  Year  Conflict Stock Displacement  \
# 0          Abyei Area  2022                      56000.0
# 1         Afghanistan  2022                    4394000.0
# 2              Angola  2022                          NaN
# 3             Albania  2022                          NaN
# 4           Argentina  2022                          NaN
#
#    Conflict Internal Displacements  Disaster Internal Displacements  \
# 0                          56000.0                          29000.0
# 1                          32000.0                         220000.0
# 2                              NaN                           1800.0
# 3                              NaN                            320.0
# 4                              NaN                            730.0
#
#    Disaster Stock Displacement
# 0                          NaN
# 1                    2164000.0
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
#2nd dataset for second project: Ecological threat indexs measuring the risks on food security, population growth, water shortage, and natural disaster.
#the link is: https://www.visionofhumanity.org/public-release-data/

# %%
Ethreat=pd.read_excel("https://github.com/shimjide123/datman/raw/main/ETR_Public_Release_Data_2022.xlsx")

# %%
Ethreat.head()
# Out:
#                     Country  Food Risk Score  Natural Disasters Score  \
# 0                   Burundi                5                        5
# 1  Central African Republic                5                        5
# 2     Republic of the Congo                5                        5
# 3                     Kenya                5                        5
# 4                Mozambique                5                        5
#
#    Rapid Population Growth Score  Water Risk Score
# 0                              5                 5
# 1                              5                 5
# 2                              5                 5
# 3                              5                 5
# 4                              5                 5

# %%
Ethreat.rename(columns={'Country': 'Countries_and_areas'}, inplace=True)

# %%
#merge the above 2 datasets first
Secondproject=pd.merge(Ethreat, displacement, how='inner', on=['Countries_and_areas'],indicator=True) ##I use "inner" merge, keeping obs with both values of displacement and ecological threat only, as I only need to see how both types of values interact.
Secondproject.head(131)
# Out:
#           Countries_and_areas  Food Risk Score  Natural Disasters Score  \
# 0                     Burundi                5                        5
# 1    Central African Republic                5                        5
# 2                       Kenya                5                        5
# 3                  Mozambique                5                        5
# 4                      Malawi                5                        5
# ..                        ...              ...                      ...
# 126                   Belgium                1                        2
# 127                    Cyprus                1                        2
# 128                   Germany                1                        2
# 129                   Finland                1                        1
# 130                    France                1                        2
#
#      Rapid Population Growth Score  Water Risk Score  Year  \
# ...

# %%
Secondproject['_merge'].value_counts()
# Out:
# both          135
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
Secondproject['Countries_and_areas'][Secondproject['_merge']=='both'].unique()
# Out:
# array(['Burundi', 'Central African Republic', 'Kenya', 'Mozambique',
#        'Malawi', 'Niger', 'Somalia', 'South Sudan', 'Chad', 'Uganda',
#        'Yemen', 'Afghanistan', 'Benin', 'Cameroon', 'Nigeria', 'Zimbabwe',
#        'Angola', 'Ethiopia', 'Guinea', 'Haiti', 'Iraq', 'Madagascar',
#        'Mauritania', 'Rwanda', 'Sudan', 'Senegal', 'Sierra Leone',
#        'Tanzania', 'Zambia', 'Burkina Faso', 'Ecuador', 'Ghana',
#        'Guatemala', 'Cambodia', 'Mali', 'Philippines', 'Solomon Islands',
#        'Syria', 'Togo', 'Tajikistan', 'Venezuela', 'Djibouti', 'Honduras',
#        'Libya', 'Myanmar', 'Mayotte', 'Nepal', 'Pakistan', 'Peru',
#        'Papua New Guinea', 'Belize', 'Bolivia', 'Dominican Republic',
#        'Morocco', 'Mongolia', 'Nicaragua', 'Eswatini', 'Vanuatu',
#        'Indonesia', 'Sri Lanka', 'El Salvador',
#        'Turks and Caicos Islands', 'Colombia', 'Cuba', 'Algeria', 'Iran',
#        'Mauritius', 'New Caledonia', 'Panama', 'Suriname', 'Tonga',
# ...

# %%
Secondproject['_merge'].value_counts() #.plot(kind='barh')
Secondproject['Countries_and_areas'][Secondproject['_merge']=='left_only']
Secondproject['Countries_and_areas'][Secondproject['_merge']=='right_only']
# Out:
# Series([], Name: Countries_and_areas, dtype: object)

# %%
pd.crosstab(Secondproject["Countries_and_areas"],merged["_merge"])
# Out:
# _merge                    both
# Countries_and_areas
# Albania                      1
# Angola                       1
# Azerbaijan                   1
# Bangladesh                   1
# Brazil                       1
# Burkina Faso                 1
# Burundi                      1
# Central African Republic     1
# Chad                         1
# Chile                        1
# Croatia                      1
# El Salvador                  1
# Fiji                         1
# Finland                      1
# France                       1
# French Polynesia             1
# Georgia                      1
# Ghana                        1
# Greece                       1
# Guatemala                    1
# Guinea                       1
# Guyana                       1
# Haiti                        1
# India                        1
# Iran                         1
# Ireland                      1
# Italy                        1
# Latvia                       1
# ...

# %%
Secondproject.fillna('') #just some data cleaning removing the "NaN" values
# Out:
#           Countries_and_areas  Food Risk Score  Natural Disasters Score  \
# 0                     Burundi                5                        5
# 1    Central African Republic                5                        5
# 2                       Kenya                5                        5
# 3                  Mozambique                5                        5
# 4                      Malawi                5                        5
# ..                        ...              ...                      ...
# 130                    France                1                        2
# 131                    Kosovo                2                        1
# 132                   Denmark                1                        1
# 133            United Kingdom                1                        1
# 134                   Iceland                1                        1
#
#      Rapid Population Growth Score  Water Risk Score  Year  \
# ...

# %%
#third dataset for second project: indicators of World Happiness Report 2023, as happiness is correlated with the living condition of human beings.
#link:https://www.kaggle.com/datasets/ajaypalsinghlo/world-happiness-report-2023

# %%
Happiness=pd.read_csv('https://github.com/shimjide123/datman/raw/main/WHR_2023.csv').head(5)

# %%
Happiness.head()
# Out:
#        country                        region  happiness_score  gdp_per_capita  \
# 0      Finland                Western Europe            7.804           1.888
# 1      Denmark                Western Europe            7.586           1.949
# 2      Iceland                Western Europe            7.530           1.926
# 3       Israel  Middle East and North Africa            7.473           1.833
# 4  Netherlands                Western Europe            7.403           1.942
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.585                    0.535                         0.772
# 1           1.548                    0.537                         0.734
# 2           1.620                    0.559                         0.738
# 3           1.521                    0.577                         0.569
# 4           1.488                    0.545                         0.672
#
#    generosity  perceptions_of_corruption
# ...

# %%
Happiness.rename(columns={'country': 'Countries_and_areas'}, inplace=True)

# %%
#let's start merging the 3rd dataset into the second project
project2nd=Happiness.merge(Secondproject, on='Countries_and_areas', how='outer')
project2nd.head()
# Out:
#   Countries_and_areas                        region  happiness_score  \
# 0             Finland                Western Europe            7.804
# 1             Denmark                Western Europe            7.586
# 2             Iceland                Western Europe            7.530
# 3              Israel  Middle East and North Africa            7.473
# 4         Netherlands                Western Europe            7.403
#
#    gdp_per_capita  social_support  healthy_life_expectancy  \
# 0           1.888           1.585                    0.535
# 1           1.949           1.548                    0.537
# 2           1.926           1.620                    0.559
# 3           1.833           1.521                    0.577
# 4           1.942           1.488                    0.545
#
#    freedom_to_make_life_choices  generosity  perceptions_of_corruption  \
# 0                         0.772       0.126                      0.535
# ...

# %%
project2nd['_merge'].value_counts() #.plot(kind='barh')
project2nd['Countries_and_areas'][project2nd['_merge']=='left_only']
project2nd['Countries_and_areas'][project2nd['_merge']=='right_only']
# Out:
# Series([], Name: Countries_and_areas, dtype: object)

# %%
project2nd['_merge'].value_counts()
# Out:
# both          135
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
project2nd.head()
# Out:
#   Countries_and_areas                        region  happiness_score  \
# 0             Finland                Western Europe            7.804
# 1             Denmark                Western Europe            7.586
# 2             Iceland                Western Europe            7.530
# 3              Israel  Middle East and North Africa            7.473
# 4         Netherlands                Western Europe            7.403
#
#    gdp_per_capita  social_support  healthy_life_expectancy  \
# 0           1.888           1.585                    0.535
# 1           1.949           1.548                    0.537
# 2           1.926           1.620                    0.559
# 3           1.833           1.521                    0.577
# 4           1.942           1.488                    0.545
#
#    freedom_to_make_life_choices  generosity  perceptions_of_corruption  \
# 0                         0.772       0.126                      0.535
# ...

# %%
#change the order of columns to put the column "Year" to the front
order=['Countries_and_areas',	'region','Year',	'happiness_score',	'gdp_per_capita',	'social_support',	'healthy_life_expectancy',	'freedom_to_make_life_choices',	'generosity',	'perceptions_of_corruption',	'Food Risk Score',	'Natural Disasters Score',	'Rapid Population Growth Score',	'Water Risk Score',	'Conflict Stock Displacement',	'Conflict Internal Displacements',	'Disaster Internal Displacements',	'Disaster Stock Displacement',	'_merge']

# %%
pro2nd=project2nd[order]
pro2nd.head() #that is the final merged I wanna show
# Out:
#   Countries_and_areas                        region    Year  happiness_score  \
# 0             Finland                Western Europe  2022.0            7.804
# 1             Denmark                Western Europe  2022.0            7.586
# 2             Iceland                Western Europe  2022.0            7.530
# 3              Israel  Middle East and North Africa  2022.0            7.473
# 4         Netherlands                Western Europe     NaN            7.403
#
#    gdp_per_capita  social_support  healthy_life_expectancy  \
# 0           1.888           1.585                    0.535
# 1           1.949           1.548                    0.537
# 2           1.926           1.620                    0.559
# 3           1.833           1.521                    0.577
# 4           1.942           1.488                    0.545
#
#    freedom_to_make_life_choices  generosity  perceptions_of_corruption  \
# 0                         0.772       0.126                      0.535
# ...

# %%
pro2nd=pro2nd.query("Year==2022 & _merge == 'both'") #subset using query
pro2nd
# Out:
#     Countries_and_areas                        region    Year  \
# 0               Finland                Western Europe  2022.0
# 1               Denmark                Western Europe  2022.0
# 2               Iceland                Western Europe  2022.0
# 3                Israel  Middle East and North Africa  2022.0
# 5               Burundi                           NaN  2022.0
# ..                  ...                           ...     ...
# 131              Cyprus                           NaN  2022.0
# 132             Germany                           NaN  2022.0
# 133              France                           NaN  2022.0
# 134              Kosovo                           NaN  2022.0
# 135      United Kingdom                           NaN  2022.0
#
#      happiness_score  gdp_per_capita  social_support  healthy_life_expectancy  \
# 0              7.804           1.888           1.585                    0.535
# ...

# %%
pro2nd=pro2nd.fillna('')
pro2nd.head()
# Out:
#   Countries_and_areas                        region    Year happiness_score  \
# 0             Finland                Western Europe  2022.0           7.804
# 1             Denmark                Western Europe  2022.0           7.586
# 2             Iceland                Western Europe  2022.0            7.53
# 3              Israel  Middle East and North Africa  2022.0           7.473
# 5             Burundi                                2022.0
#
#   gdp_per_capita social_support healthy_life_expectancy  \
# 0          1.888          1.585                   0.535
# 1          1.949          1.548                   0.537
# 2          1.926           1.62                   0.559
# 3          1.833          1.521                   0.577
# 5
#
#   freedom_to_make_life_choices generosity perceptions_of_corruption  \
# 0                        0.772      0.126                     0.535
# 1                        0.734      0.208                     0.525
# ...

# %%
pro2nd=pro2nd.reset_index(drop=True)
pro2nd.head()
# Out:
#   Countries_and_areas                        region    Year happiness_score  \
# 0             Finland                Western Europe  2022.0           7.804
# 1             Denmark                Western Europe  2022.0           7.586
# 2             Iceland                Western Europe  2022.0            7.53
# 3              Israel  Middle East and North Africa  2022.0           7.473
# 4             Burundi                                2022.0
#
#   gdp_per_capita social_support healthy_life_expectancy  \
# 0          1.888          1.585                   0.535
# 1          1.949          1.548                   0.537
# 2          1.926           1.62                   0.559
# 3          1.833          1.521                   0.577
# 4
#
#   freedom_to_make_life_choices generosity perceptions_of_corruption  \
# 0                        0.772      0.126                     0.535
# 1                        0.734      0.208                     0.525
# ...
