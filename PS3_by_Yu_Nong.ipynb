# %% [markdown]
# <a href="https://colab.research.google.com/github/shimjide123/datman/blob/main/PS3_by_Yu_Nong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader as pdr
from pandas_datareader import wb
from pandas.io.formats.style import Styler
#s4 = Styler(df4, uuid_len=0, cell_ids=False)

from google.colab import files

# %%
import numpy as np

# %%
Marriage=pd.read_excel('https://github.com/shimjide123/datman/raw/main/UNICEF%20Child-marriage-database.xlsx')

# %%
Marriage.head()
# Out:
#   Countries and areas        Child marriage (%)                Unnamed: 2  \
# 0                 NaN                       NaN                       NaN
# 1                 NaN  Female Married by 15 (%)  Female Married by 18 (%)
# 2                 NaN                       NaN                       NaN
# 3         Afghanistan                     4.201                    28.257
# 4             Albania                     1.387                    11.761
#
#                Unnamed: 3
# 0                     NaN
# 1  Male Married by 18 (%)
# 2                     NaN
# 3                     7.3
# 4                     1.2

# %%
Marriage.rename(columns={'Child marriage (%)': 'Female_married_by_15(%)'}, inplace=True)
Marriage.rename(columns={'Unnamed: 2': 'Female_married_by_18(%)'}, inplace=True)
Marriage.rename(columns={'Unnamed: 3': 'Male_married_by_18(%)'}, inplace=True)
Marriage.rename(columns={'Countries and areas': 'Countries'}, inplace=True)

# %%
Marriage['Female_married_by_18(%)'] = pd.to_numeric(Marriage['Female_married_by_18(%)'], errors='coerce')
Marriage['Female_married_by_15(%)'] = pd.to_numeric(Marriage['Female_married_by_15(%)'], errors='coerce')
Marriage['Male_married_by_18(%)'] = pd.to_numeric(Marriage['Male_married_by_18(%)'], errors='coerce')

# %%
Marriage.dtypes
# Out:
# Countries                   object
# Female_married_by_15(%)    float64
# Female_married_by_18(%)    float64
# Male_married_by_18(%)      float64
# dtype: object

# %%
Marriage=Marriage.drop(Marriage.index[[0,1,2]],axis=0)

# %%
Marriage.reset_index(drop=True)
Marriage.head()
# Out:
#      Countries  Female_married_by_15(%)  Female_married_by_18(%)  \
# 3  Afghanistan                    4.201                   28.257
# 4      Albania                    1.387                   11.761
# 5      Algeria                    0.000                    3.800
# 6      Andorra                      NaN                      NaN
# 7       Angola                    7.902                   30.331
#
#    Male_married_by_18(%)
# 3                    7.3
# 4                    1.2
# 5                    NaN
# 6                    NaN
# 7                    6.0

# %%
Marriage=Marriage.fillna('')
Marriage.head()
# Out:
#      Countries Female_married_by_15(%) Female_married_by_18(%)  \
# 3  Afghanistan                   4.201                  28.257
# 4      Albania                   1.387                  11.761
# 5      Algeria                     0.0                     3.8
# 6      Andorra
# 7       Angola                   7.902                  30.331
#
#   Male_married_by_18(%)
# 3                   7.3
# 4                   1.2
# 5
# 6
# 7                   6.0

# %%
for x in Marriage.index:
 if Marriage.loc[x,"Female_married_by_15(%)"]=='':
    Marriage.drop(x,inplace=True)

Marriage.head()
# Out:
#       Countries Female_married_by_15(%) Female_married_by_18(%)  \
# 3   Afghanistan                   4.201                  28.257
# 4       Albania                   1.387                  11.761
# 5       Algeria                     0.0                     3.8
# 7        Angola                   7.902                  30.331
# 10    Argentina                   2.386                   15.45
#
#    Male_married_by_18(%)
# 3                    7.3
# 4                    1.2
# 5
# 7                    6.0
# 10

# %%
for x in Marriage.index:
 if Marriage.loc[x,"Female_married_by_18(%)"]=='':
    Marriage.drop(x,inplace=True)

# %%
for x in Marriage.index:
 if Marriage.loc[x,"Male_married_by_18(%)"]=='':
    Marriage.drop(x,inplace=True)

# %%
Marriage.head()
# Out:
#       Countries Female_married_by_15(%) Female_married_by_18(%)  \
# 3   Afghanistan                   4.201                  28.257
# 4       Albania                   1.387                  11.761
# 7        Angola                   7.902                  30.331
# 11      Armenia                   0.042                     5.3
# 14   Azerbaijan                     1.9                    11.0
#
#    Male_married_by_18(%)
# 3                    7.3
# 4                    1.2
# 7                    6.0
# 11                   0.4
# 14                   0.4

# %%
Marriage.reset_index(drop=True)
# Out:
#                           Countries Female_married_by_15(%)  \
# 0                       Afghanistan                   4.201
# 1                           Albania                   1.387
# 2                            Angola                   7.902
# 3                           Armenia                   0.042
# 4                        Azerbaijan                     1.9
# ..                              ...                     ...
# 100              Sub-Saharan Africa                   9.922
# 101     Eastern and Southern Africa                   8.758
# 102         West and Central Africa                  10.968
# 103       Least developed countries                  10.356
# 104                           World                    4.24
#
#     Female_married_by_18(%) Male_married_by_18(%)
# 0                    28.257                   7.3
# 1                    11.761                   1.2
# 2                    30.331                   6.0
# ...

# %%
Completion=pd.read_excel('https://github.com/shimjide123/datman/raw/main/Completion_rate_2022_formatted%20(1).xlsx')

# %%
Completion.head()
# Out:
#      Countries Regions Development Regions      Total  Female_completion_rate  \
# 0  Afghanistan      SA     Least Developed  22.895340               14.365360
# 1      Albania     ECA      More Developed  77.947960               79.857063
# 2      Algeria    MENA      Less Developed  46.431679               59.164452
# 3      Andorra     ECA      More Developed        NaN                     NaN
# 4       Angola     SSA     Least Developed  18.743900               15.210190
#
#    Male_completion_rate  Rural_completion_rate  Urban_completion_rate  \
# 0             32.315559              16.607441              38.913071
# 1             76.226807              69.100288              83.281387
# 2             34.630589              35.473091              52.634720
# 3                   NaN                    NaN                    NaN
# 4             23.698139               3.587311              24.791439
#
#     female_population  male_population  Urban_percentage
# ...

# %%
Completion=Completion.fillna('')
Completion.head()
# Out:
#      Countries Regions Development Regions      Total Female_completion_rate  \
# 0  Afghanistan      SA     Least Developed   22.89534               14.36536
# 1      Albania     ECA      More Developed   77.94796              79.857063
# 2      Algeria    MENA      Less Developed  46.431679              59.164452
# 3      Andorra     ECA      More Developed
# 4       Angola     SSA     Least Developed    18.7439               15.21019
#
#   Male_completion_rate Rural_completion_rate Urban_completion_rate  \
# 0            32.315559             16.607441             38.913071
# 1            76.226807             69.100288             83.281387
# 2            34.630589             35.473091              52.63472
# 3
# 4            23.698139              3.587311             24.791439
#
#    female_population male_population Urban_percentage
# 0          1380667.0       1458082.0         0.254949
# 1            53510.0         61841.0         0.603189
# ...

# %%
Completion.dtypes
# Out:
# Countries                 object
# Regions                   object
# Development Regions       object
# Total                     object
# Female_completion_rate    object
# Male_completion_rate      object
# Rural_completion_rate     object
# Urban_completion_rate     object
#  female_population        object
# male_population           object
# Urban_percentage          object
# dtype: object

# %%
for x in Completion.index:
 if Completion.loc[x,"Female_completion_rate"]=='':
    Completion.drop(x,inplace=True)

for x in Completion.index:
 if Completion.loc[x,"Total"]=='':
    Completion.drop(x,inplace=True)

for x in Completion.index:
 if Completion.loc[x,"Male_completion_rate"]=='':
    Completion.drop(x,inplace=True)

for x in Completion.index:
 if Completion.loc[x,"Rural_completion_rate"]=='':
    Completion.drop(x,inplace=True)

for x in Completion.index:
 if Completion.loc[x,"Urban_completion_rate"]=='':
    Completion.drop(x,inplace=True)


Completion.reset_index(drop=True)
# Out:
#        Countries Regions Development Regions      Total  \
# 0    Afghanistan      SA     Least Developed   22.89534
# 1        Albania     ECA      More Developed   77.94796
# 2        Algeria    MENA      Less Developed  46.431679
# 3         Angola     SSA     Least Developed    18.7439
# 4        Armenia     ECA      Less Developed  74.582832
# ..           ...     ...                 ...        ...
# 106      Uruguay     LAC      Less Developed  37.685638
# 107     Viet Nam     EAP      Less Developed       55.5
# 108        Yemen    MENA     Least Developed       29.5
# 109       Zambia     SSA     Least Developed   29.66189
# 110     Zimbabwe     SSA      Less Developed       15.3
#
#     Female_completion_rate Male_completion_rate Rural_completion_rate  \
# 0                 14.36536            32.315559             16.607441
# 1                79.857063            76.226807             69.100288
# 2                59.164452            34.630589             35.473091
# ...

# %%
merged1 = pd.merge(Marriage, Completion, how='inner', on=['Countries'],indicator=True) #outer=keep all
merged1.head(131)
# Out:
#                       Countries Female_married_by_15(%)  \
# 0                   Afghanistan                   4.201
# 1                       Albania                   1.387
# 2                        Angola                   7.902
# 3                       Armenia                   0.042
# 4                    Bangladesh                  15.483
# ..                          ...                     ...
# 79                      Ukraine                     0.1
# 80  United Republic of Tanzania                   5.205
# 81                     Viet Nam                   1.098
# 82                       Zambia                   5.166
# 83                     Zimbabwe                   5.418
#
#    Female_married_by_18(%) Male_married_by_18(%) Regions Development Regions  \
# 0                   28.257                   7.3      SA     Least Developed
# 1                   11.761                   1.2     ECA      More Developed
# ...

# %%
merged1['_merge'].value_counts() #.plot(kind='barh')
merged1['Countries'][merged1['_merge']=='left_only']
merged1['Countries'][merged1['_merge']=='right_only']
# Out:
# Series([], Name: Countries, dtype: object)

# %%
labor=pd.read_excel('https://github.com/shimjide123/datman/raw/main/XLS_Child-labour-database_June-2023%20(1).xlsx')

# %%
display(merged1, labor)
# Out:
#                       Countries Female_married_by_15(%)  \
# 0                   Afghanistan                   4.201
# 1                       Albania                   1.387
# 2                        Angola                   7.902
# 3                       Armenia                   0.042
# 4                    Bangladesh                  15.483
# ..                          ...                     ...
# 79                      Ukraine                     0.1
# 80  United Republic of Tanzania                   5.205
# 81                     Viet Nam                   1.098
# 82                       Zambia                   5.166
# 83                     Zimbabwe                   5.418
#
#    Female_married_by_18(%) Male_married_by_18(%) Regions Development Regions  \
# 0                   28.257                   7.3      SA     Least Developed
# 1                   11.761                   1.2     ECA      More Developed
# ...

# %%
merged =labor.merge(merged1, on='Countries', how='outer')

# %%
merged
# Out:
#                               Countries Total_Child_labor Male_Child_labor  \
# 0                           Afghanistan                13             14.2
# 1                               Albania               3.3              3.6
# 2                               Algeria               2.5              2.9
# 3                               Andorra                 -                -
# 4                                Angola            18.724             16.6
# ..                                  ...               ...              ...
# 197  Venezuela (Bolivarian Republic of)                 -                -
# 198                            Viet Nam              6.94            6.359
# 199                               Yemen                 -                -
# 200                              Zambia                23             22.9
# 201                            Zimbabwe              27.9             33.1
#
# ...

# %%
merged['_merge'].value_counts() #.plot(kind='barh')
merged['Countries'][merged['_merge']=='left_only']
merged['Countries'][merged['_merge']=='right_only']
# Out:
# Series([], Name: Countries, dtype: object)

# %%
merged.dtypes
# Out:
# Countries                    object
# Total_Child_labor            object
# Male_Child_labor             object
# Female_Child_labor           object
# Female_married_by_15(%)      object
# Female_married_by_18(%)      object
# Male_married_by_18(%)        object
# Regions                      object
# Development Regions          object
# Total                        object
# Female_completion_rate       object
# Male_completion_rate         object
# Rural_completion_rate        object
# Urban_completion_rate        object
#  female_population           object
# male_population              object
# Urban_percentage             object
# _merge                     category
# dtype: object

# %%
merged['Female_married_by_18(%)'] = pd.to_numeric(merged['Female_married_by_18(%)'], errors='coerce')
merged['Female_married_by_15(%)'] = pd.to_numeric(merged['Female_married_by_15(%)'], errors='coerce')
merged['Male_married_by_18(%)'] = pd.to_numeric(merged['Male_married_by_18(%)'], errors='coerce')

# %%
merged['Male_married_by_18(%)'].fillna('',inplace=True)
merged['Female_married_by_15(%)'].fillna('',inplace=True)
merged['Female_married_by_18(%)'].fillna('',inplace=True)
merged['Total_Child_labor'].fillna('',inplace=True)
merged['Male_Child_labor'].fillna('',inplace=True)
merged['Female_Child_labor'].fillna('',inplace=True)
merged['Regions'].fillna('',inplace=True)
merged['Development Regions'].fillna('',inplace=True)
merged['Female_completion_rate'].fillna('',inplace=True)
merged['Male_completion_rate'].fillna('',inplace=True)
merged['Rural_completion_rate'].fillna('',inplace=True)
merged['Urban_completion_rate'].fillna('',inplace=True)
merged['Total'].fillna('',inplace=True)

merged.replace('-','',inplace=True)

merged
# Out:
#                               Countries Total_Child_labor Male_Child_labor  \
# 0                           Afghanistan                13             14.2
# 1                               Albania               3.3              3.6
# 2                               Algeria               2.5              2.9
# 3                               Andorra
# 4                                Angola            18.724             16.6
# ..                                  ...               ...              ...
# 197  Venezuela (Bolivarian Republic of)
# 198                            Viet Nam              6.94            6.359
# 199                               Yemen
# 200                              Zambia                23             22.9
# 201                            Zimbabwe              27.9             33.1
#
#     Female_Child_labor Female_married_by_15(%) Female_married_by_18(%)  \
# 0                 11.7                   4.201                  28.257
# ...

# %%
merged.drop(columns=" female_population",inplace=True)

# %%
merged.drop(columns=["male_population","Urban_percentage"],inplace=True)

# %%
merged
# Out:
#                               Countries Total_Child_labor Male_Child_labor  \
# 0                           Afghanistan                13             14.2
# 1                               Albania               3.3              3.6
# 2                               Algeria               2.5              2.9
# 3                               Andorra
# 4                                Angola            18.724             16.6
# ..                                  ...               ...              ...
# 197  Venezuela (Bolivarian Republic of)
# 198                            Viet Nam              6.94            6.359
# 199                               Yemen
# 200                              Zambia                23             22.9
# 201                            Zimbabwe              27.9             33.1
#
#     Female_Child_labor Female_married_by_15(%) Female_married_by_18(%)  \
# 0                 11.7                   4.201                  28.257
# ...

# %%
order=['Countries','Regions','Development Regions','Total_Child_labor','Male_Child_labor', 'Female_Child_labor', 'Female_married_by_15(%)','Female_married_by_18(%)','Male_married_by_18(%)','Total','Female_completion_rate','Male_completion_rate','Rural_completion_rate','Urban_completion_rate','_merge']

# %%
Merged2=merged[order]
Merged2.head()
# Out:
#      Countries Regions Development Regions Total_Child_labor Male_Child_labor  \
# 0  Afghanistan      SA     Least Developed                13             14.2
# 1      Albania     ECA      More Developed               3.3              3.6
# 2      Algeria                                           2.5              2.9
# 3      Andorra
# 4       Angola     SSA     Least Developed            18.724             16.6
#
#   Female_Child_labor Female_married_by_15(%) Female_married_by_18(%)  \
# 0               11.7                   4.201                  28.257
# 1                  3                   1.387                  11.761
# 2                  2
# 3
# 4              19.87                   7.902                  30.331
#
#   Male_married_by_18(%)     Total Female_completion_rate Male_completion_rate  \
# 0                   7.3  22.89534               14.36536            32.315559
# 1                   1.2  77.94796              79.857063            76.226807
# 2
# 3
# ...

# %%
displacement=pd.read_excel("https://github.com/shimjide123/datman/raw/main/IDMC_Internal_Displacement_Conflict-Violence_Disasters.xlsx")

# %%
displacement.head()
# Out:
#   ISO3         Name  Year  Conflict Stock Displacement  \
# 0  AB9   Abyei Area  2022                      56000.0
# 1  AFG  Afghanistan  2022                    4394000.0
# 2  AGO       Angola  2022                          NaN
# 3  ALB      Albania  2022                          NaN
# 4  ARG    Argentina  2022                          NaN
#
#    Conflict Stock Displacement (Raw)  Conflict Internal Displacements  \
# 0                            55705.0                          56000.0
# 1                          4393749.0                          32000.0
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#    Conflict Internal Displacements (Raw)  Disaster Internal Displacements  \
# 0                                55705.0                          29000.0
# ...

# %%
displacement.rename(columns={'Name': 'Countries'}, inplace=True)

# %%
displacement.drop(columns=["ISO3","Conflict Stock Displacement (Raw)", "Conflict Internal Displacements (Raw)"],inplace=True)

# %%
displacement.drop(columns=["Disaster Internal Displacements (Raw)", "Disaster Stock Displacement (Raw)"],inplace=True)

# %%
displacement.head()
# Out:
#      Countries  Year  Conflict Stock Displacement  \
# 0   Abyei Area  2022                      56000.0
# 1  Afghanistan  2022                    4394000.0
# 2       Angola  2022                          NaN
# 3      Albania  2022                          NaN
# 4    Argentina  2022                          NaN
#
#    Conflict Internal Displacements  Disaster Internal Displacements  \
# 0                          56000.0                          29000.0
# 1                          32000.0                         220000.0
# 2                              NaN                           1800.0
# 3                              NaN                            320.0
# 4                              NaN                            730.0
#
#    Disaster Stock Displacement
# 0                          NaN
# 1                    2164000.0
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
Firstproject=displacement.merge(Merged2, on='Countries', how='outer')

# %%
Firstproject.head()
# Out:
#      Countries    Year  Conflict Stock Displacement  \
# 0   Abyei Area  2022.0                      56000.0
# 1  Afghanistan  2022.0                    4394000.0
# 2       Angola  2022.0                          NaN
# 3      Albania  2022.0                          NaN
# 4    Argentina  2022.0                          NaN
#
#    Conflict Internal Displacements  Disaster Internal Displacements  \
# 0                          56000.0                          29000.0
# 1                          32000.0                         220000.0
# 2                              NaN                           1800.0
# 3                              NaN                            320.0
# 4                              NaN                            730.0
#
#    Disaster Stock Displacement Regions Development Regions Total_Child_labor  \
# 0                          NaN     NaN                 NaN               NaN
# 1                    2164000.0      SA     Least Developed                13
# ...

# %%
pd.crosstab(Firstproject["Countries"],Firstproject["_merge"])
# Out:
# _merge                       both
# Countries
# Afghanistan                     1
# Albania                         1
# Angola                          1
# Armenia                         1
# Bangladesh                      1
# ...                           ...
# Ukraine                         1
# United Republic of Tanzania     1
# Viet Nam                        1
# Zambia                          1
# Zimbabwe                        1
#
# [84 rows x 1 columns]

# %%
Firstproject['_merge'].value_counts()
# Out:
# both          84
# left_only      0
# right_only     0
# Name: _merge, dtype: int64

# %%
Firstproject=Firstproject.query("Year == 2022 & _merge == 'both'")
Firstproject
# Out:
#         Countries    Year  Conflict Stock Displacement  \
# 1     Afghanistan  2022.0                    4394000.0
# 2          Angola  2022.0                          NaN
# 3         Albania  2022.0                          NaN
# 5         Armenia  2022.0                       8400.0
# 9         Burundi  2022.0                       8500.0
# ..            ...     ...                          ...
# 145      Viet Nam  2022.0                          NaN
# 147         Samoa  2022.0                          NaN
# 150  South Africa  2022.0                          NaN
# 151        Zambia  2022.0                          NaN
# 152      Zimbabwe  2022.0                          NaN
#
#      Conflict Internal Displacements  Disaster Internal Displacements  \
# 1                            32000.0                         220000.0
# 2                                NaN                           1800.0
# 3                                NaN                            320.0
# ...

# %%
Firstproject.fillna('')
# Out:
#         Countries    Year Conflict Stock Displacement  \
# 1     Afghanistan  2022.0                   4394000.0
# 2          Angola  2022.0
# 3         Albania  2022.0
# 5         Armenia  2022.0                      8400.0
# 9         Burundi  2022.0                      8500.0
# ..            ...     ...                         ...
# 145      Viet Nam  2022.0
# 147         Samoa  2022.0
# 150  South Africa  2022.0
# 151        Zambia  2022.0
# 152      Zimbabwe  2022.0
#
#     Conflict Internal Displacements Disaster Internal Displacements  \
# 1                           32000.0                        220000.0
# 2                                                            1800.0
# 3                                                             320.0
# 5                            7600.0
# 9                             600.0                         13000.0
# ..                              ...                             ...
# ...
